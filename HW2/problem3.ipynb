# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

# %%
# import train dataset
train = pd.read_csv('train.csv')
train.head()
# Out:
#    Unnamed: 0     price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0           1  221900.0         3       1.00         1180      5650     1.0
# 1           2  538000.0         3       2.25         2570      7242     2.0
# 2           3  180000.0         2       1.00          770     10000     1.0
# 3           4  604000.0         4       3.00         1960      5000     1.0
# 4           5  510000.0         3       2.00         1680      8080     1.0
#
#    waterfront  view  condition  grade  sqft_above  sqft_basement  yr_built  \
# 0           0     0          3      7        1180              0      1955
# 1           0     0          3      7        2170            400      1951
# 2           0     0          3      6         770              0      1933
# 3           0     0          5      7        1050            910      1965
# 4           0     0          3      8        1680              0      1987
#
#    yr_renovated  zipcode      lat     long  sqft_living15  sqft_lot15
# 0             0    98178  47.5112 -122.257           1340        5650
# 1          1991    98125  47.7210 -122.319           1690        7639
# 2             0    98028  47.7379 -122.233           2720        8062
# 3             0    98136  47.5208 -122.393           1360        5000
# 4             0    98074  47.6168 -122.045           1800        7503

# %%
# import test dataset
test = pd.read_csv('test.csv')
test.head()
# Out:
#    Unnamed: 0          id             date     price  bedrooms  bathrooms  \
# 0        1001  3131200640  20150427T000000  700000.0         4       2.00
# 1        1002   984000710  20141022T000000  270000.0         3       2.00
# 2        1003  4167300350  20140508T000000  258000.0         4       1.75
# 3        1004  2826049282  20140614T000000  530000.0         3       2.50
# 4        1005  8946750030  20141218T000000  245000.0         3       2.25
#
#    sqft_living  sqft_lot  floors  waterfront  ...  grade  sqft_above  \
# 0         1830      4590     2.0           0  ...      8        1830
# 1         1560      8853     1.0           0  ...      7        1560
# 2         1730      8320     1.0           0  ...      7        1230
# 3         1930      7214     2.0           0  ...      8        1930
# 4         1422      3677     2.0           0  ...      7        1422
#
#    sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# 0              0      1908             0    98105  47.6593 -122.327
# 1              0      1967             0    98058  47.4312 -122.171
# 2            500      1977             0    98023  47.3270 -122.361
# 3              0      2005             0    98125  47.7191 -122.309
# 4              0      2012             0    98092  47.3204 -122.178
#
#    sqft_living15  sqft_lot15
# 0           1650        4590
# 1           1610        8750
# 2           1840        9800
# 3           1930        7266
# 4           1677        3677
#
# [5 rows x 22 columns]

# %%
# TRAIN:
# ignore columns: id, date and zipcode
# also ignore price column because this is the response and what we are trying to predict
columns_to_drop = ['Unnamed: 0', 'zipcode', 'price']
x_train = train.drop(columns=columns_to_drop)
x_train.head()
# Out:
#    bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  view  \
# 0         3       1.00         1180      5650     1.0           0     0
# 1         3       2.25         2570      7242     2.0           0     0
# 2         2       1.00          770     10000     1.0           0     0
# 3         4       3.00         1960      5000     1.0           0     0
# 4         3       2.00         1680      8080     1.0           0     0
#
#    condition  grade  sqft_above  sqft_basement  yr_built  yr_renovated  \
# 0          3      7        1180              0      1955             0
# 1          3      7        2170            400      1951          1991
# 2          3      6         770              0      1933             0
# 3          5      7        1050            910      1965             0
# 4          3      8        1680              0      1987             0
#
#        lat     long  sqft_living15  sqft_lot15
# 0  47.5112 -122.257           1340        5650
# 1  47.7210 -122.319           1690        7639
# 2  47.7379 -122.233           2720        8062
# 3  47.5208 -122.393           1360        5000
# 4  47.6168 -122.045           1800        7503

# %%
# TEST:
# ignore columns: id, date and zipcode
# also ignore price column because this is the response and what we are trying to predict
columns_to_drop = ['Unnamed: 0', 'id', 'date', 'zipcode', 'price']
x_test = test.drop(columns=columns_to_drop)
x_test.head()
# Out:
#    bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  view  \
# 0         4       2.00         1830      4590     2.0           0     0
# 1         3       2.00         1560      8853     1.0           0     0
# 2         4       1.75         1730      8320     1.0           0     0
# 3         3       2.50         1930      7214     2.0           0     0
# 4         3       2.25         1422      3677     2.0           0     0
#
#    condition  grade  sqft_above  sqft_basement  yr_built  yr_renovated  \
# 0          3      8        1830              0      1908             0
# 1          3      7        1560              0      1967             0
# 2          3      7        1230            500      1977             0
# 3          3      8        1930              0      2005             0
# 4          3      7        1422              0      2012             0
#
#        lat     long  sqft_living15  sqft_lot15
# 0  47.6593 -122.327           1650        4590
# 1  47.4312 -122.171           1610        8750
# 2  47.3270 -122.361           1840        9800
# 3  47.7191 -122.309           1930        7266
# 4  47.3204 -122.178           1677        3677

# %%
# scale the data so that each feature has a mean of 0 and standard deviation of 1
scaler = StandardScaler()

# scale train dataset
for col in x_train:
    train_scaled = x_train[col].values.reshape(-1, 1) #reshape
    x_train[col] = scaler.fit_transform(train_scaled) 

# scale test dataset
for col in x_test:
    test_scaled = x_test[col].values.reshape(-1, 1) #reshape
    x_test[col] = scaler.fit_transform(test_scaled) 


# check mean and standard deviation of each feature to double check that scaling worked
for feature in x_train:
    mean = x_train.mean()
    std = x_train.var()

for feature in x_test:
    mean = x_test.mean()
    std = x_test.var()

# organize all variables into a table
stats_train = {
    'mean': mean,
    'std': std
}

stats_test = {
    'mean': mean,
    'std': std
}

feature_data_train = pd.DataFrame(stats_train)
feature_data_test = pd.DataFrame(stats_test)
feature_data_test
# Out:
#                        mean       std
# bedrooms      -1.385558e-16  1.001001
# bathrooms      2.122746e-16  1.001001
# sqft_living   -2.113865e-16  1.001001
# sqft_lot      -1.421085e-17  1.001001
# floors        -8.704149e-17  1.001001
# waterfront    -2.842171e-17  1.001001
# view          -8.792966e-17  1.001001
# condition      1.776357e-16  1.001001
# grade         -3.215206e-16  1.001001
# sqft_above     2.842171e-17  1.001001
# sqft_basement  3.241851e-17  1.001001
# yr_built      -2.083667e-15  1.001001
# yr_renovated  -1.065814e-17  1.001001
# lat            2.316725e-14  1.001001
# long          -2.620659e-14  1.001001
# sqft_living15 -7.283063e-17  1.001001
# sqft_lot15     3.197442e-17  1.001001

# %%
# divide the price by 1000 for all rows in the train dataset
y_train = train['price'] / 1000
y_train
# Out:
# 0      221.90
# 1      538.00
# 2      180.00
# 3      604.00
# 4      510.00
#         ...
# 995    291.00
# 996    199.95
# 997    553.50
# 998    189.95
# 999    289.00
# Name: price, Length: 1000, dtype: float64

# %%
# divide the price by 1000 for all rows in the test dataset
y_test = test['price'] / 1000
y_test
# Out:
# 0      700.0
# 1      270.0
# 2      258.0
# 3      530.0
# 4      245.0
#        ...
# 995    307.0
# 996    194.0
# 997    180.0
# 998    465.0
# 999    722.5
# Name: price, Length: 1000, dtype: float64

# %%
# implement closed form solution:

# need to organize training data features into a matrix:
matrix_train = x_train.values
print(matrix_train)

price_matrix_train = y_train.values
print(price_matrix_train)
# Out:
# [[-0.40982347 -1.44988843 -0.98164572 ... -0.35519332 -0.96563661
#   -0.3128578 ]
#  [-0.40982347  0.28318404  0.58457767 ... -0.7998304  -0.44332966
#   -0.23355563]
#  [-1.58410276 -1.44988843 -1.44362529 ... -0.18307573  1.09374507
#   269.95   493.     370.    2250.     305.     400.     320.     715.
#   650.     218.     500.     460.     232.5    408.2    522.     675.
#  1355.     249.95   210.     429.95   737.5    710.     470.    1100.
#   650.    1216.     422.12   625.     385.2    500.     308.     565.
#   581.     361.     345.     419.     347.     625.    2400.     379.
#   310.     250.     682.     246.5    325.     310.95  1100.     287.5
#   431.     226.     825.     175.     465.75   659.     595.     350.
#   270.     662.5    249.9    324.5    430.     419.95   285.     332.
#   282.     320.     428.75   330.     456.5    352.     664.     628.
#   512.     254.     535.8    287.653  438.     450.     327.     370.5
#   265.     450.     425.     166.6    245.     565.     539.9    910.
#   280.     275.     467.     457.5    381.156  289.999  642.45   469.95
#   795.     785.     860.    1095.     147.5    390.     229.     185.
#   414.9    200.     225.     720.     930.    1270.     700.     466.
#   374.     480.     740.    1010.     395.     340.     209.     431.65
#   980.     660.     730.     291.5    905.     800.     839.9    200.
#   300.     530.     314.95   255.     550.     435.     234.     615.
#   205.     384.     324.     645.     570.     324.     270.     290.
#   250.     342.     255.     800.     451.     990.     288.4    420.
#   359.     390.     300.     545.     288.349  299.9    891.    1200.
#   378.     299.995  253.     350.     565.     315.     570.     971.
#   915.     419.     260.    1321.5    369.95  1029.9    435.     601.
#   460.5    720.     851.     550.     700.     323.     345.5    378.
#   650.     385.     425.     210.     630.     335.     196.5    582.8
#   440.     752.5    532.5    265.     397.5    524.25   765.     648.
#   469.5    237.5    216.     427.2    280.     718.     420.     379.
#   326.1    535.     283.     260.     399.     484.95   640.     585.
#   645.     253.     178.5    291.     199.95   553.5    189.95   289.   ]

# %%
# implement closed form solution:

# need to organize features into a matrix for test:
matrix_test = x_test.values
print(matrix_test)

price_matrix_test = y_test.values
print(price_matrix_test)
# Out:
# [[ 0.61971096 -0.12765819 -0.28513503 ... -0.83161535 -0.49282611
#   -0.32497811]
#  [-0.45245333 -0.12765819 -0.57291228 ...  0.32371455 -0.55042162
#   -0.17705032]
#  [ 0.61971096 -0.44286359 -0.39171919 ... -1.08341802 -0.21924741
#   -0.13971278]
#  ...
#  [-0.45245333 -1.38847979 -1.15912519 ... -0.00955369 -1.34235996
#   -0.12001278]
#  [ 0.61971096  0.18754721  0.25844422 ...  1.31611331 -0.26244405
#   -0.04256405]
#  [ 0.61971096  0.50275261  0.38634522 ...  0.46442781  1.06225281
#   -0.13615682]]
# [ 700.     270.     258.     530.     245.     563.     515.     325.
#   540.     280.3    460.     475.     900.     538.2    429.     164.808
#   520.     475.     283.     321.5    840.     287.     375.     349.5
#   446.45   315.     271.31   315.     245.     543.115  900.    2450.
#   554.     249.9    768.     980.     395.     415.     380.     566.
#   218.5    550.     512.031  197.5    470.     590.     465.     499.
#   515.     716.5    410.     850.    1050.     648.     620.     935.
#   379.     699.     528.     425.     249.5   1035.48   790.     399.95
#   275.     550.     140.     250.     318.     505.     470.5    360.
#  1242.5    986.     515.     320.     310.     356.7    775.     325.
#   265.     740.     230.     315.     432.     467.     255.     316.5
#   190.     490.     378.     598.8    333.8    690.     320.    1249.
#   335.     840.     608.25   550.     240.     998.     275.     284.2
#  1715.    2400.     930.8    930.     215.     480.     483.945  347.
#   232.5    390.     550.     590.     420.85   345.     429.8    302.
#   800.     250.     605.     412.     252.     375.     725.     471.75
#   490.     439.     355.     250.     780.     409.     420.     200.
#   830.     695.     815.     210.     635.     562.5    402.5    555.
#   310.     500.     430.    1600.     627.5    335.     962.     299.
#   399.95   322.     430.     307.     194.     180.     465.     722.5  ]

# %%
# theta = ((x^T)*x)^-1 * (x^T)y

def closed_form_calc(matrix, price_matrix):

    x_t = matrix.T @ matrix

    x_t_inv = np.linalg.inv(x_t)

    x_t_y = matrix.T @ price_matrix

    theta = x_t_inv @ x_t_y

    return theta

theta_train = closed_form_calc(matrix_train, price_matrix_train)
theta_train
# Out:
# array([ -20.60779929,   24.6002802 , -117.55227383,   11.97226633,
#           7.39278699,   64.21902716,   48.09557824,   13.1863707 ,
#          91.16319067,  180.55046312,   70.53244241,  -67.64311741,
#          17.27137953,   78.37573693,   -1.03520308,   45.57765781,
#         -12.93009098])

# %%
# find MSE and r^2 value for train:

MSE_train = mean_squared_error(price_matrix_train, theta_train)
r2_train = r2_score(price_matrix_train, theta_train)

print('MSE metric: ', MSE_train)
print('R squared metric: ', r2_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[45], line 4
#       1 # find MSE and r^2 value for train:
# ----> 4 MSE_train = mean_squared_error(price_matrix_train, theta_train)
#       5 r2_train = r2_score(price_matrix_train, theta_train)
#       7 print('MSE metric: ', MSE_train)
#
# File ~/anaconda3/lib/python3.11/site-packages/sklearn/utils/_param_validation.py:211, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     205 try:
#     206     with config_context(
#     207         skip_parameter_validation=(
#     208             prefer_skip_nested_validation or global_skip_validation
#     209         )
#     210     ):
# --> 211         return func(*args, **kwargs)
#     212 except InvalidParameterError as e:
#     213     # When the function is just a wrapper around an estimator, we allow
#     214     # the function to delegate validation to the estimator, but we replace
#     215     # the name of the estimator by the name of the function in the error
#     216     # message to avoid confusion.
#     217     msg = re.sub(
#     218         r"parameter of \w+ must be",
#     219         f"parameter of {func.__qualname__} must be",
#     220         str(e),
#     221     )
#
# File ~/anaconda3/lib/python3.11/site-packages/sklearn/metrics/_regression.py:474, in mean_squared_error(y_true, y_pred, sample_weight, multioutput, squared)
#     404 @validate_params(
#     405     {
#     406         "y_true": ["array-like"],
#    (...)
#     415     y_true, y_pred, *, sample_weight=None, multioutput="uniform_average", squared=True
#     416 ):
#     417     """Mean squared error regression loss.
#     418
#     419     Read more in the :ref:`User Guide <mean_squared_error>`.
#    (...)
#     472     0.825...
#     473     """
# --> 474     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#     475         y_true, y_pred, multioutput
#     476     )
#     477     check_consistent_length(y_true, y_pred, sample_weight)
#     478     output_errors = np.average((y_true - y_pred) ** 2, axis=0, weights=sample_weight)
#
# File ~/anaconda3/lib/python3.11/site-packages/sklearn/metrics/_regression.py:99, in _check_reg_targets(y_true, y_pred, multioutput, dtype)
#      65 def _check_reg_targets(y_true, y_pred, multioutput, dtype="numeric"):
#      66     """Check that y_true and y_pred belong to the same regression task.
#      67
#      68     Parameters
#    (...)
#      97         correct keyword.
#      98     """
# ---> 99     check_consistent_length(y_true, y_pred)
#     100     y_true = check_array(y_true, ensure_2d=False, dtype=dtype)
#     101     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#
# File ~/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:409, in check_consistent_length(*arrays)
#     407 uniques = np.unique(lengths)
#     408 if len(uniques) > 1:
# --> 409     raise ValueError(
#     410         "Found input variables with inconsistent numbers of samples: %r"
#     411         % [int(l) for l in lengths]
#     412     )
#
# ValueError: Found input variables with inconsistent numbers of samples: [1000, 17]

# %%
theta_test = closed_form_calc(matrix_test, price_matrix_test)
theta_test
# Out:
# array([ -53.00731021,   -2.41748907,  738.09572622,   28.29228042,
#          -7.18303165,   74.43708466,   52.98815515,   22.15453383,
#          92.71466834, -430.58318482, -278.07817508,  -72.50375394,
#          -2.23381801,   77.61091444,  -10.3665892 ,   23.68905403,
#         -23.85038144])
